# %% [markdown]
# # **VERSION 6**
#
# ---

# %% [markdown]
# ##**A) pre-work segment**

# %% [markdown]
# ###**1. download and install modules**

# %%
# !pip install ConfigParser
# Out:
# Collecting ConfigParser
#   Downloading https://files.pythonhosted.org/packages/4b/6b/01baa293090240cf0562cc5eccb69c6f5006282127f2b846fad011305c79/configparser-5.0.0-py3-none-any.whl
# Installing collected packages: ConfigParser
# Successfully installed ConfigParser-5.0.0

# %%
#pip install googlemaps

# %% [markdown]
# ###**2. mount drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ###**3. import needed classes and methods**

# %%
import configparser
from textblob import TextBlob
import tweepy
import matplotlib.pyplot as plt
import regex as re
import spacy
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
import googlemaps
#import sys
#import os
import pandas as pd
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %% [markdown]
# ###**4. download from imported modules**

# %%
nltk.download("vader_lexicon")
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# ###**5. connect & authenticate**

# %%
# !ls '/content/drive/My Drive/Colab Notebooks/uemprojectgroup covid_1.properties'
# Out:
# '/content/drive/My Drive/Colab Notebooks/uemprojectgroup covid_1.properties'

# %%
config=configparser.RawConfigParser()
config.read('/content/drive/My Drive/Colab Notebooks/uemprojectgroup covid_1.properties')
print(config.sections())
# Out:
# ['twitter', 'gmaps']

# %%
consumerKey=config.get('twitter','consumerKey')
consumerSecret=config.get('twitter','consumerSecret')
accessToken=config.get('twitter','accessToken')
accessTokenSecret=config.get('twitter','accessTokenSecret')

# %%
#print(consumerKey,"\n",consumerSecret,"\n",accessToken,"\n",accessTokenSecret)

# %%
auth=tweepy.OAuthHandler(consumer_key=consumerKey,consumer_secret=consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api=tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

# %%
gmaps=googlemaps.Client(key=config.get('gmaps','gApiKey'))

# %% [markdown]
# ##**B) methods for work segment**

# %% [markdown]
# ###**1. send tweet**

# %%
#while True:
#  api=tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

# %%
#tw=tweepy.Cursor(api.search, q="covid"+"-filter:retweets",lang="English").items(100)
#for i in tw:
#  print([i.text,i.user.screen_name,i.user.location,i.geo])

# %%
def sendTweet():
  tweet=input("enter your tweet: ")
  api.update_status(tweet)

# %% [markdown]
# ###**2. create dataset with specific keyword**

# %%
def searchTweetWithKeyword():

  covid_list=[]


  searchTerm,noOfRecords=input("enter keyword and max no. of records needed:").split()
  noOfRecords=int(noOfRecords)

  #a_tweets=tweepy.Cursor(api.search, q=searchTerm+"-filter:retweets",lang="English").items(noOfRecords)
  a_tweets=tweepy.Cursor(api.search, q=searchTerm+"-filter:retweets",lang="en").items(noOfRecords)

  for i in a_tweets:
    covid_list.append([i.text,i.user.screen_name,i.user.location,i.geo])


  covid_df=pd.DataFrame(covid_list,columns=["tweets","user_name","location","geo"])
  totalNoOfRecords=len(covid_df)

  print("total no. of records: ",totalNoOfRecords)
  print("records: ")
  display(covid_df)

  return covid_df,totalNoOfRecords

# %% [markdown]
# ###**3. check tweet sentiments using TextBlob**

# %%
def percentage(part,whole):
  return part*100/whole

# %%
def checkSentimentTextBlob(covid_df,noOfRecords):
  positive=0
  negative=0
  neutral=0
  polarity=0

  for i in range(noOfRecords):
    textblob_text=TextBlob(covid_df.iloc[i,0])
    value=textblob_text.sentiment.polarity
    polarity+=value
    
    if value<0:
        negative+=1
    elif value==0:
        neutral+=1
    elif value>0:
        positive+=1

  print("raw numbers:\npositive=",positive,"\nnegative=",negative,"\nneutral=",neutral,"\npolarity=",polarity)
  
  positive=format(percentage(positive,noOfRecords),'.2f')
  negative=format(percentage(negative,noOfRecords),'.2f')
  neutral=format(percentage(neutral,noOfRecords),'.2f')
  polarity=format(percentage(polarity,noOfRecords),'.2f')

  print("percentage:\npositive=",positive,"\nnegative=",negative,"\nneutral=",neutral,"\npolarity=",polarity)

# %% [markdown]
# ###**4. count tweet from each location (city)**

# %%
def tweetLocations(covid_df,noOfRecords):
  
  display(covid_df['location'].value_counts())

# %% [markdown]
# ###**5. clean tweets**

# %%
def cleanTweets(covid_df,noOfRecords):
  for i in range(noOfRecords):
    text=covid_df.iloc[i,0]
    
    text=re.sub("@[\w]*","",text)
    text=re.sub("RT @[\w]*:","",text)
    text=re.sub("https?://[a-zA-Z0-9./]*","",text)
    text=re.sub("\n","",text)
    text=re.sub("#","",text)
    text=re.sub("[`~!@#$%^&*()+\[\]{}\\:;'\",=<>?/.|-]|[_]","",text)
    text= re.sub("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", "",text)

    covid_df.iloc[i,0]=text
  
  display(covid_df)
  return covid_df,noOfRecords

# %% [markdown]
# ###**6. convert dataframe to csv**

# %%
def toCSV(covid_df):
  covid_df.to_csv('covid_csv.csv')

# %% [markdown]
# ###**7. show entites in text**

# %%
def showEntities(covid_df,noOfRecords):
  nlp=spacy.load('en_core_web_sm')

  covid_df['entities']=covid_df['tweets'].apply(lambda tweet: [(ent.text,ent.label_) if (not ent.text.startswith('#')) else "" for ent in nlp(tweet).ents])
  
  display(covid_df)
  return covid_df,noOfRecords

# %% [markdown]
# ###**8. check tweet sentiments using Sentiment Intensity Analyzer**

# %%
def tweetSentimentIntensityAnalyzer(covid_df,noOfRecords):
  sid=SentimentIntensityAnalyzer()
  covid_df['sentiment']=covid_df['tweets'].apply(lambda tweet: sid.polarity_scores(tweet))
  display(covid_df)
  return covid_df,noOfRecords

# %% [markdown]
# ###**9. categorizing by location using googlemaps api**

# %%
#not working till we set payment details

# %%
def getCountry(location):
  result=gmaps.geocode(location)
  result=(result[0]['formatted_address'].split(','))[-1].strip()
  return result

# %%
def tweetLocationsUsingGmaps(covid_df,noOfRecords):
  covid_df['country']=covid_df['location'].apply(lambda location: "" if(not location.strip() ) else getCountry(location))

  print(covid_df['country'].value_counts())

  return covid_df,noOfRecords

# %% [markdown]
# ###**10. filter tweets in dataset by keywords**

# %%
def search(keyword,tweets):
  temp=[]
  for t in tweets:
    #print(type(t))
    #print(t)
    #print(re.search(keyword,t))
    if re.search(keyword.lower(),t.lower()):
      temp.append(True)
    else:
      temp.append(False)
  return temp

# %%
def filterDataSet(covid_df,noOfRecords):
  
  while True:
    searchTerm=input("enter keyword:")
    #covid_df=covid_df[ lambda covid_df.tweets,searchTerm: return re.search(keyword,text) ]
    ncovid_df=covid_df[ search(searchTerm,covid_df.tweets) ]
    display(ncovid_df)
    ch1=input("do you want to keep the changes?\n y or n:")
    if  (ch1=='y' or ch1=='Y'):
      covid_df=ncovid_df
      

    ch2=input("do you want to search for another keyword from within your dataset?\n y or n:")
    if not (ch2=='y' or ch2=='Y'):
      break

  print("FINAL DATASET:")
  totalNoOfRecords=len(covid_df)
  print("no. of records:",totalNoOfRecords)
  print("records:")
  display(covid_df)
  return covid_df,totalNoOfRecords

# %% [markdown]
# ###**11. sentiment related to medical and other facilities related to covid state wise for India or city wise for some cities**

# %%
covid,noOfRecords=searchTweetWithKeyword()
covid_df=covid.copy()
# Out:
# enter keyword and max no. of records needed:covid 2500
# total no. of records:  2500
# records:
#                                                  tweets  ...   geo
# 0     Wisconsin COVID Cases Increase To 51,049 Death...  ...  None
# 1     #TrumpNSC #OBrien #COVID POSITIVE Thus he expo...  ...  None
# 2     @9NEWS You know who else didn't test positive ...  ...  None
# 3     ‘We see no point in wearing a face mask,’ Swed...  ...  None
# 4     @tedlieu @realDonaldTrump Like they always say...  ...  None
# ...                                                 ...  ...   ...
# 2495  Apparently there is over 700 covid cases today...  ...  None
# 2496  @AE7Q_ @Phil_Johnson_ As with all reports of C...  ...  None
# 2497  @WDSU DrHebert knows he talks BS HogWash. Chil...  ...  None
# 2498  @Zeddary That's exactly how we"ll all look if ...  ...  None
# 2499                       Covid can straight fuck off.  ...  None
#
# [2500 rows x 4 columns]

# %%
covid_df,noOfRecords=cleanTweets(covid_df,noOfRecords)
# Out:
#                                                  tweets  ...   geo
# 0     Wisconsin COVID Cases Increase To 51049 Deaths...  ...  None
# 1     TrumpNSC OBrien COVID POSITIVE Thus he exposed...  ...  None
# 2      You know who else didnt test positive for COV...  ...  None
# 3     ‘We see no point in wearing a face mask’ Swede...  ...  None
# 4       Like they always say everything is bigger in...  ...  None
# ...                                                 ...  ...   ...
# 2495  Apparently there is over 700 covid cases today...  ...  None
# 2496    As with all reports of COVID deaths I questi...  ...  None
# 2497   DrHebert knows he talks BS HogWash Children u...  ...  None
# 2498   Thats exactly how well all look if he forces ...  ...  None
# 2499                        Covid can straight fuck off  ...  None
#
# [2500 rows x 4 columns]

# %%
#def customSol1(covid_df,noOfRecords):

stop_words = set(stopwords.words('english')) 
ftokens_list=[]
for i in range(noOfRecords):
  tokens=word_tokenize(covid_df.iloc[i,0].lower())
  filtered_tokens = [w  for w in tokens if not w in stop_words]
  ftokens_list.append(filtered_tokens)
covid_df['ftokens']=pd.Series(ftokens_list)

display(covid_df)
# Out:
#                                                  tweets  ...                                            ftokens
# 0     Wisconsin COVID Cases Increase To 51049 Deaths...  ...  [wisconsin, covid, cases, increase, 51049, dea...
# 1     TrumpNSC OBrien COVID POSITIVE Thus he exposed...  ...  [trumpnsc, obrien, covid, positive, thus, expo...
# 2      You know who else didnt test positive for COV...  ...  [know, else, didnt, test, positive, covidmarty...
# 3     ‘We see no point in wearing a face mask’ Swede...  ...  [‘, see, point, wearing, face, mask, ’, sweden...
# 4       Like they always say everything is bigger in...  ...  [like, always, say, everything, bigger, texas,...
# ...                                                 ...  ...                                                ...
# 2495  Apparently there is over 700 covid cases today...  ...  [apparently, 700, covid, cases, today, victori...
# 2496    As with all reports of COVID deaths I questi...  ...  [reports, covid, deaths, question, whether, in...
# 2497   DrHebert knows he talks BS HogWash Children u...  ...  [drhebert, knows, talks, bs, hogwash, children...
# 2498   Thats exactly how well all look if he forces ...  ...  [thats, exactly, well, look, forces, us, take,...
# 2499                        Covid can straight fuck off  ...                            [covid, straight, fuck]
#
# [2500 rows x 5 columns]

# %%
def get_wordnet_pos(treebank_tag):

  if treebank_tag.startswith('J'):
    return wordnet.ADJ
  elif treebank_tag.startswith('V'):
    return wordnet.VERB
  elif treebank_tag.startswith('N'):
    return wordnet.NOUN
  elif treebank_tag.startswith('R'):
    return wordnet.ADV
  else:
    return wordnet.NOUN

# %%
def postag(tokens):
  pos=nltk.pos_tag(tokens)
  res=[]
  lemmatizer = WordNetLemmatizer()
  for i in pos:
    res.append(lemmatizer.lemmatize(i[0], pos=get_wordnet_pos(i[1]) ) )
  return res

# %%
# text="looking ok forward to your show is basically an exciting adventure"
# tokens=word_tokenize(text)
# postag(tokens)

# %%
covid_df['lemma']=covid_df['ftokens'].apply(lambda ftoken: postag(ftoken) )
display(covid_df)
# Out:
#                                                  tweets  ...                                              lemma
# 0     Wisconsin COVID Cases Increase To 51049 Deaths...  ...  [wisconsin, covid, case, increase, 51049, deat...
# 1     TrumpNSC OBrien COVID POSITIVE Thus he exposed...  ...  [trumpnsc, obrien, covid, positive, thus, expo...
# 2      You know who else didnt test positive for COV...  ...  [know, else, didnt, test, positive, covidmarty...
# 3     ‘We see no point in wearing a face mask’ Swede...  ...  [‘, see, point, wear, face, mask, ’, sweden, ’...
# 4       Like they always say everything is bigger in...  ...  [like, always, say, everything, big, texas, in...
# ...                                                 ...  ...                                                ...
# 2495  Apparently there is over 700 covid cases today...  ...  [apparently, 700, covid, case, today, victoria...
# 2496    As with all reports of COVID deaths I questi...  ...  [report, covid, death, question, whether, indi...
# 2497   DrHebert knows he talks BS HogWash Children u...  ...  [drhebert, know, talk, bs, hogwash, child, 10,...
# 2498   Thats exactly how well all look if he forces ...  ...  [thats, exactly, well, look, force, u, take, r...
# 2499                        Covid can straight fuck off  ...                            [covid, straight, fuck]
#
# [2500 rows x 6 columns]

# %%
noOfRecords=covid_df.shape[0]
medic_terms=['medical','hospital','hospital bed','spread','outbreak','help','need','reinforcement','affected','discharge','tested','death']
medic_terms=postag(medic_terms)
print(medic_terms)

# for i in range(noOfRecords):
#   display(covid_df[ medic_lemmas is in for l in covid_df.loc[i,'lemma'] ])
temp=[]
for i in range(noOfRecords):
  flag=0
  for j in medic_terms:
    for k in covid_df.loc[i,'lemma']:
      if j==k:
        temp.append(True)
        flag=1
        break
    if flag==1:
      break
  if flag==0:
    temp.append(False)

xcovid=covid_df[temp].copy()
xcovid.reset_index(inplace=True)
xcovid.drop('index',axis=1,inplace=True)
display(xcovid)
noOfRecords=xcovid.shape[0]
# Out:
# ['medical', 'hospital', 'hospital bed', 'spread', 'outbreak', 'help', 'need', 'reinforcement', 'affected', 'discharge', 'test', 'death']
#                                                 tweets  ...                                              lemma
# 0    Wisconsin COVID Cases Increase To 51049 Deaths...  ...  [wisconsin, covid, case, increase, 51049, deat...
# 1     You know who else didnt test positive for COV...  ...  [know, else, didnt, test, positive, covidmarty...
# 2     You know what would help getting schools open...  ...  [know, would, help, get, school, open, full, t...
# 3    The COVID19 outbreak on the Rutgers football t...  ...  [covid19, outbreak, rutgers, football, team, r...
# 4    Of the 27000 tests yesterday only 76 were posi...  ...  [27000, test, yesterday, 76, positive, previou...
# ..                                                 ...  ...                                                ...
# 460   Comrade Schutzstaffel sorry to hear about you...  ...  [comrade, schutzstaffel, sorry, hear, hoax, il...
# 461      How many more kids had covid and didn’t ge...  ...  [many, kid, covid, ’, get, test, bc, asymptoma...
# 462  The first dog to test positive for coronavirus...  ...  [first, dog, test, positive, coronavirus, u, d...
# 463  US passes 150000 coronavirus deaths amid fresh...  ...  [u, pass, 150000, coronavirus, death, amid, fr...
# 464    As with all reports of COVID deaths I questi...  ...  [report, covid, death, question, whether, indi...
#
# [465 rows x 6 columns]

# %%
positive=[]
neutral=[]
negative=[]

for i in range(noOfRecords):
    textblob_text=TextBlob(xcovid.iloc[i,0])
    value=textblob_text.sentiment.polarity
    
    
    if value<0:
        positive.append(0)
        neutral.append(0)
        negative.append(1)

    elif value==0:
        positive.append(0)
        neutral.append(1)
        negative.append(0)

    elif value>0:
        positive.append(1)
        neutral.append(0)
        negative.append(0)

xcovid['positive']=pd.Series(positive)
xcovid['neutral']=pd.Series(neutral)
xcovid['negative']=pd.Series(negative)

display(xcovid)
# Out:
#                                                 tweets  ... negative
# 0    Wisconsin COVID Cases Increase To 51049 Deaths...  ...        0
# 1     You know who else didnt test positive for COV...  ...        0
# 2     You know what would help getting schools open...  ...        0
# 3    The COVID19 outbreak on the Rutgers football t...  ...        0
# 4    Of the 27000 tests yesterday only 76 were posi...  ...        1
# ..                                                 ...  ...      ...
# 460   Comrade Schutzstaffel sorry to hear about you...  ...        1
# 461      How many more kids had covid and didn’t ge...  ...        0
# 462  The first dog to test positive for coronavirus...  ...        0
# 463  US passes 150000 coronavirus deaths amid fresh...  ...        0
# 464    As with all reports of COVID deaths I questi...  ...        0
#
# [465 rows x 9 columns]

# %%
group=pd.DataFrame( )
group['positive']=xcovid.groupby('location').positive.sum()
group['neutral']=xcovid.groupby('location').neutral.sum()
group['negative']=xcovid.groupby('location').negative.sum()
display(group)
# Out:
#                               positive  neutral  negative
# location
#                                     51       68        25
#                                      0        1         0
#  Iowa                                0        1         0
# !!!!!!!!!!RINGSIDE!!!!!!!!!!         0        0         1
# 1/2 in CA, 1/2 in CO                 0        0         2
# ...                                ...      ...       ...
# this twisted reality                 0        0         1
# trenton nj                           0        1         0
# wherever God takes me                0        0         1
# ÜT: 33.74484,-84.405579              1        0         0
# 🌱💜 | she/her                         0        1         0
#
# [259 rows x 3 columns]

# %%
group.to_csv('sen.csv')

# %%
covid.to_csv('covid.csv')

# %%
covid_df.to_csv('fcovid.csv')

# %%
xcovid.to_csv('xcovid.csv')

# %% [markdown]
# ##**C) main method segment**

# %%
def main():
  covid_df=None
  noOfRecords=None

  print(
  "press 0 to display dataframe\n"
  "press 1 to send tweet\n"
  "press 2 to find tweets with keyword\n"
  "press 3 to check sentiments using TextBlob\n"
  "press 4 to categorize and count by location (city)\n"
  "press 5 to clean tweets\n"
  "press 6 to covert dataframe into csv\n"
  "press 7 to show entities in text\n"
  "press 8 to check tweet sentiments using Sentiment Intensity Analyzer\n"
  "press 9 to categorize and count by location (country) using googlemaps api\n"
  "press 10 to filter tweets in dataset by keywords"
  "press 100 to exit\n")

  while True:
    ch=int(input("choose: "))
    if ch==0:
        display(covid_df)
    elif ch==1:
      sendTweet()
    elif ch==2:
      covid_df,noOfRecords=searchTweetWithKeyword()
    elif ch==3:
      checkSentimentTextBlob(covid_df,noOfRecords)
    elif ch==4:
      tweetLocations(covid_df,noOfRecords)
    elif ch==5:
      covid_df,noOfRecords=cleanTweets(covid_df,noOfRecords)
    elif ch==6:
      toCSV(covid_df)
    elif ch==7:
      covid_df,noOfRecords=showEntities(covid_df,noOfRecords)
    elif ch==8:
      covid_df,noOfRecords=tweetSentimentIntensityAnalyzer(covid_df,noOfRecords)
    elif ch==9:
      covid_df,noOfRecords=tweetLocationsUsingGmaps(covid_df,noOfRecords)
    elif ch==10:
      covid_df,noOfRecords=filterDataSet(covid_df,noOfRecords)
    elif ch==100:
      break
    else:
      print("INVALID CHOICE !")

# %%
if __name__=="__main__":
 main()
# Out:
# press 0 to display dataframe
# press 1 to send tweet
# press 2 to find tweets with keyword
# press 3 to check sentiments using TextBlob
# press 4 to categorize and count by location (city)
# press 5 to clean tweets
# press 6 to covert dataframe into csv
# press 7 to show entities in text
# press 8 to check tweet sentiments using Sentiment Intensity Analyzer
# press 9 to categorize and count by location (country) using googlemaps api
# press 10 to filter tweets in dataset by keywordspress 100 to exit
#
# choose: 1
# enter your tweet: testing v6
# choose: 2
# enter keyword and max no. of records needed:covid 500
# total no. of records:  500
# records:
#                                                 tweets  ...   geo
# 0    Gawat! Kasus Infeksi Covid-19 Tembus 100.000, ...  ...  None
# 1    @firdzaradiany Emangnya karyawan test covid-19...  ...  None
# 2    My friend lost her father to COVID-19. Please ...  ...  None
# 3    CG PPHT 2020: Exam (Cancelled), Admit Card, Pa...  ...  None
# 4    @rafetavlc @pablocasado_ Pablo Casado pide man...  ...  None
# ..                                                 ...  ...   ...
# 495  Badan Kebijakan Fiskal akan mengadakan Call Fo...  ...  None
# 496  No compartir utensilios ni platos, usar la mas...  ...  None
# 497  @repjerrynadler @tedwheeler do they have a per...  ...  None
# 498  The Secretary of State for Health Matt Hancock...  ...  None
# 499  @robbystarbuck @realDonaldTrump @SenatorBoxer ...  ...  None
#
# [500 rows x 4 columns]
# choose: 3
# raw numbers:
# positive= 105
# negative= 82
# neutral= 313
# polarity= 4.646969922438669
# percentage:
# positive= 21.00
# negative= 16.40
# neutral= 62.60
# polarity= 0.93
# choose: 4
#                        155
# India                    8
# London                   4
# New York, NY             4
# Australia                4
#                       ...
# Харків                   1
# brighton                 1
# West Cornwall, UK        1
# Glasgow                  1
# Hessen Deutschland       1
# Name: location, Length: 291, dtype: int64
# choose: 5
#                                                 tweets  ...   geo
# 0    Gawat! Kasus Infeksi Covid-19 Tembus 100.000, ...  ...  None
# 1     Emangnya karyawan test covid-19 ke CEO? Kok b...  ...  None
# 2    My friend lost her father to COVID-19. Please ...  ...  None
# 3    CG PPHT 2020: Exam (Cancelled), Admit Card, Pa...  ...  None
# 4      Pablo Casado pide mando único para combatir ...  ...  None
# ..                                                 ...  ...   ...
# 495  Badan Kebijakan Fiskal akan mengadakan Call Fo...  ...  None
# 496  No compartir utensilios ni platos, usar la mas...  ...  None
# 497    do they have a permit and is this sanitary. ...  ...  None
# 498  The Secretary of State for Health Matt Hancock...  ...  None
# 499      It censorship. The media platforms have be...  ...  None
#
# [500 rows x 4 columns]
# choose: 7
#                                                 tweets  ...                                           entities
# 0    Gawat! Kasus Infeksi Covid-19 Tembus 100.000, ...  ...  [(Kasus Infeksi, PERSON), (Tembus, GPE), (Baka...
# 1     Emangnya karyawan test covid-19 ke CEO? Kok b...  ...  [(Kok bisa, PERSON), (karyawannya?Karyawannya,...
# 2    My friend lost her father to COVID-19. Please ...  ...                                                 []
# 3    CG PPHT 2020: Exam (Cancelled), Admit Card, Pa...  ...  [(Admit Card, PERSON), (Pattern, NORP), (Sylla...
# 4      Pablo Casado pide mando único para combatir ...  ...  [(mando único para, ORG), (de alarma le h…, PE...
# ..                                                 ...  ...                                                ...
# 495  Badan Kebijakan Fiskal akan mengadakan Call Fo...  ...  [(Badan Kebijakan Fiskal, PERSON), (Call For P...
# 496  No compartir utensilios ni platos, usar la mas...  ...  [(el tiempo de las visitas…, ORG), (consejos d...
# 497    do they have a permit and is this sanitary. ...  ...                                                 []
# 498  The Secretary of State for Health Matt Hancock...  ...  [(State, ORG), (Matt Hancock, PERSON), (COVID,...
# 499      It censorship. The media platforms have be...  ...                                                 []
#
# [500 rows x 5 columns]
# choose: 8
#                                                 tweets  ...                                          sentiment
# 0    Gawat! Kasus Infeksi Covid-19 Tembus 100.000, ...  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1     Emangnya karyawan test covid-19 ke CEO? Kok b...  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2    My friend lost her father to COVID-19. Please ...  ...  {'neg': 0.113, 'neu': 0.493, 'pos': 0.394, 'co...
# 3    CG PPHT 2020: Exam (Cancelled), Admit Card, Pa...  ...  {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'comp...
# 4      Pablo Casado pide mando único para combatir ...  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ..                                                 ...  ...                                                ...
# 495  Badan Kebijakan Fiskal akan mengadakan Call Fo...  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 496  No compartir utensilios ni platos, usar la mas...  ...  {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'comp...
# 497    do they have a permit and is this sanitary. ...  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 498  The Secretary of State for Health Matt Hancock...  ...  {'neg': 0.375, 'neu': 0.625, 'pos': 0.0, 'comp...
# 499      It censorship. The media platforms have be...  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [500 rows x 6 columns]
# choose: 6
# choose: 10
# enter keyword:censor
#                                                 tweets  ...                                          sentiment
# 35    The censorship of covid data.  See frontline ...  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 87                    FRAUDCI is being COVID censored!  ...  {'neg': 0.321, 'neu': 0.679, 'pos': 0.0, 'comp...
# 499      It censorship. The media platforms have be...  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [3 rows x 6 columns]
# do you want to keep the changes?
#  y or n:n
# do you want to search for another keyword from within your dataset?
#  y or n:y
# enter keyword:india
#                                                 tweets  ...                                          sentiment
# 101  India has prepared five sites for the final hu...  ...  {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'comp...
# 150    India’s COVID Mortality rate is the lowest i...  ...  {'neg': 0.14, 'neu': 0.86, 'pos': 0.0, 'compou...
# 347  #HelphenIndia #lockdown #COVID #mumbai #storie...  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 379  India in better position in fighting COVID 19 ...  ...  {'neg': 0.15, 'neu': 0.601, 'pos': 0.249, 'com...
# 433  "We have completed 2,000 #VandeBharat evacuati...  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 452                  "COVID-19 in India" #coronavirus   ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [6 rows x 6 columns]
# do you want to keep the changes?
#  y or n:y
# do you want to search for another keyword from within your dataset?
#  y or n:n
# FINAL DATASET:
# no. of records: 6
# records:
#                                                 tweets  ...                                          sentiment
# 101  India has prepared five sites for the final hu...  ...  {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'comp...
# 150    India’s COVID Mortality rate is the lowest i...  ...  {'neg': 0.14, 'neu': 0.86, 'pos': 0.0, 'compou...
# 347  #HelphenIndia #lockdown #COVID #mumbai #storie...  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 379  India in better position in fighting COVID 19 ...  ...  {'neg': 0.15, 'neu': 0.601, 'pos': 0.249, 'com...
# 433  "We have completed 2,000 #VandeBharat evacuati...  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 452                  "COVID-19 in India" #coronavirus   ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [6 rows x 6 columns]
# choose: 0
#                                                 tweets  ...                                          sentiment
# 101  India has prepared five sites for the final hu...  ...  {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'comp...
# 150    India’s COVID Mortality rate is the lowest i...  ...  {'neg': 0.14, 'neu': 0.86, 'pos': 0.0, 'compou...
# 347  #HelphenIndia #lockdown #COVID #mumbai #storie...  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 379  India in better position in fighting COVID 19 ...  ...  {'neg': 0.15, 'neu': 0.601, 'pos': 0.249, 'com...
# 433  "We have completed 2,000 #VandeBharat evacuati...  ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 452                  "COVID-19 in India" #coronavirus   ...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [6 rows x 6 columns]
# choose: 100

# %% [markdown]
# ---
#
#
# # **END OF CODE, ROUGH WORK BEGINS:**
#
#
# ---

# %%
print(__name__)
# Out:
# __main__

# %%
def create_df():
  dfr=pd.DataFrame([['qwerty','be','mumbai, india','d','e'],['uiop','be','canada',None,'e'],['wasd','bi','dallas tx','d','e'],['fghjklzxc','b','european union','d','e']],columns=['A','B','C','D','E'])
  display("records:",dfr)
  return dfr

# %%
dfr=create_df()
# Out:
# 'records:'
#            A   B               C     D  E
# 0     qwerty  be   mumbai, india     d  e
# 1       uiop  be          canada  None  e
# 2       wasd  bi       dallas tx     d  e
# 3  fghjklzxc   b  european union     d  e

# %%
dfr1=pd.DataFrame([['zxcasdedc','bo','kolkata, india','de','ei'],['uiop','be','orissa','dio','eu']],columns=['A','B','C','D','E'])
dfr=dfr.append(dfr1,ignore_index=True)
dfr.drop_duplicates(inplace=True)
dfr

#df.iloc[:,[1,3]]
# Out:
#            A   B               C     D   E
# 0     qwerty  be   mumbai, india     d   e
# 1       uiop  be          canada  None   e
# 2       wasd  bi       dallas tx     d   e
# 3  fghjklzxc   b  european union     d   e
# 4  zxcasdedc  bo  kolkata, india    de  ei
# 5       uiop  be          orissa   dio  eu

# %%
dfr.iloc[3,2]
# Out:
# 'european union'

# %%
dfr['A']
# Out:
# 0       qwerty
# 1         uiop
# 2         wasd
# 3    fghjklzxc
# 4    zxcasdedc
# 5         uiop
# Name: A, dtype: object

# %%
listo=[]
for i in range(len(dfr)):
  listo.append(dfr.iloc[i,0])

print(listo)
# Out:
# ['qwerty', 'uiop', 'wasd', 'fghjklzxc', 'zxcasdedc', 'uiop']

# %%
dfr['B'].value_counts()
# Out:
# be    3
# bo    1
# b     1
# bi    1
# Name: B, dtype: int64

# %%
nlp=spacy.load('en_core_web_sm')
text = ("When Sebastian Thrun started working on self-driving cars at "
        "Google in 2007, few people outside of the company took him "
        "seriously. “I can tell you very senior CEOs of major American "
        "car companies would shake my hand and turn away because I wasn’t "
        "worth talking to,” said Thrun, in an interview with Recode earlier "
        "this week.")
print(type(text))


for ent in nlp(text).ents:
  print(ent.text,ent.label_)
# Out:
# <class 'str'>
# Sebastian NORP
# Google ORG
# 2007 DATE
# American NORP
# Recode ORG
# earlier this week DATE

# %%
dfr['A'].apply(lambda x: x+': test')
# Out:
# 0       qwerty: test
# 1         uiop: test
# 2         wasd: test
# 3    fghjklzxc: test
# 4    zxcasdedc: test
# 5         uiop: test
# Name: A, dtype: object

# %%
dfr['A'].apply(lambda x: [len(x) for i in range(len(x))])
# Out:
# 0             [6, 6, 6, 6, 6, 6]
# 1                   [4, 4, 4, 4]
# 2                   [4, 4, 4, 4]
# 3    [9, 9, 9, 9, 9, 9, 9, 9, 9]
# 4    [9, 9, 9, 9, 9, 9, 9, 9, 9]
# 5                   [4, 4, 4, 4]
# Name: A, dtype: object

# %%
dfr['A'].apply(lambda x: ["e" if i%2==0 else "o"  for i in range(len(x))])
# Out:
# 0             [e, o, e, o, e, o]
# 1                   [e, o, e, o]
# 2                   [e, o, e, o]
# 3    [e, o, e, o, e, o, e, o, e]
# 4    [e, o, e, o, e, o, e, o, e]
# 5                   [e, o, e, o]
# Name: A, dtype: object

# %%
dfr['e/o 1']=dfr['A'].apply(lambda x: ["e" if i%2==0 else "o"  for i in range(len(x))])
dfr
# Out:
#            A   B               C     D   E                        e/o 1
# 0     qwerty  be   mumbai, india     d   e           [e, o, e, o, e, o]
# 1       uiop  be          canada  None   e                 [e, o, e, o]
# 2       wasd  bi       dallas tx     d   e                 [e, o, e, o]
# 3  fghjklzxc   b  european union     d   e  [e, o, e, o, e, o, e, o, e]
# 4  zxcasdedc  bo  kolkata, india    de  ei  [e, o, e, o, e, o, e, o, e]
# 5       uiop  be          orissa   dio  eu                 [e, o, e, o]

# %%
dfr['e/o 2']=dfr['A'].apply(lambda x: [(i,"e") if i%2==0 else (i,"o")  for i in range(len(x))])
dfr
# Out:
#            A  ...                                              e/o 2
# 0     qwerty  ...   [(0, e), (1, o), (2, e), (3, o), (4, e), (5, o)]
# 1       uiop  ...                   [(0, e), (1, o), (2, e), (3, o)]
# 2       wasd  ...                   [(0, e), (1, o), (2, e), (3, o)]
# 3  fghjklzxc  ...  [(0, e), (1, o), (2, e), (3, o), (4, e), (5, o...
# 4  zxcasdedc  ...  [(0, e), (1, o), (2, e), (3, o), (4, e), (5, o...
# 5       uiop  ...                   [(0, e), (1, o), (2, e), (3, o)]
#
# [6 rows x 7 columns]

# %%
dfr['e/o 3']=dfr['A'].apply(lambda x: [(i,"e") if i%2==0 else ""  for i in range(len(x))])
dfr
# Out:
#            A  ...                                             e/o 3
# 0     qwerty  ...                    [(0, e), , (2, e), , (4, e), ]
# 1       uiop  ...                              [(0, e), , (2, e), ]
# 2       wasd  ...                              [(0, e), , (2, e), ]
# 3  fghjklzxc  ...  [(0, e), , (2, e), , (4, e), , (6, e), , (8, e)]
# 4  zxcasdedc  ...  [(0, e), , (2, e), , (4, e), , (6, e), , (8, e)]
# 5       uiop  ...                              [(0, e), , (2, e), ]
#
# [6 rows x 8 columns]

# %%
dfr.to_csv('df.csv')

# !ls
# Out:
# covid_csv.csv  df.csv  drive  sample_data

# %%
# gmaps=googlemaps.Client(key=config.get('gmaps','gApiKey'))
# geocode_result=gmaps.geocode(df.iloc[2,2])

# print(geocode_result)
# print(geocode_result[0])
# print(geocode_result[0]['formatted_address'])
# print(geocode_result[0]['formatted_address'].split(',')[-1])
# print(geocode_result[0]['formatted_address'].split(',')[-1].strip())

# %%
trial="  asd  "
print(not trial.strip())
print(not( not trial.strip()))

trial="    "
print(not trial.strip())
print(not( not trial.strip()))
# Out:
# False
# True
# True
# False

# %%
class StreamListner(tweepy.StreamListner);
def on_status(self,status):
  print(status)
def on_error(self,error,    ):
  print(error)
def on_data(self,data):
# Out:
#   File "<ipython-input-77-34a8520965fe>", line 1
#     class StreamListner(tweepy.StreamListner);
#                                              ^
# SyntaxError: invalid syntax

# %%
#covid_confirmed_df=pd.read_csv("https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")

# %%
print(u"\U0001F600")
# Out:
# 😀

# %%
text = u'This is a smiley face \U0001f602'
print(text) # with emoji

def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)

print(deEmojify(text))
# Out:
# This is a smiley face 😂
# This is a smiley face
